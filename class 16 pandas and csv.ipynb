# %%
try:
    file=open('data.csv','x')
    file.close()
except:
    pass

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df
# Out:
#    sn      name  age    address        phone
# 0   1        AJ   19  Kathmandu   9878989898
# 1   2    Bigyan   34  Kathmandu  98689698689
# 2   3   Abhinav   15  Bhaktapur   8969698608
# 3   4  Shiwansh   12   Lalitpur   7149872421
# 4   5      Josh   45    Chitwan  80797079870
# 5   6     Harry   34      Kaski  98747377382

# %%
df.head(4)
# Out:
#    sn      name  age    address        phone
# 0   1        AJ   19  Kathmandu   9878989898
# 1   2    Bigyan   34  Kathmandu  98689698689
# 2   3   Abhinav   15  Bhaktapur   8969698608
# 3   4  Shiwansh   12   Lalitpur   7149872421

# %%
df.tail()
# Out:
#    sn      name  age    address        phone
# 1   2    Bigyan   34  Kathmandu  98689698689
# 2   3   Abhinav   15  Bhaktapur   8969698608
# 3   4  Shiwansh   12   Lalitpur   7149872421
# 4   5      Josh   45    Chitwan  80797079870
# 5   6     Harry   34      Kaski  98747377382

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='sn')
df
# Out:
#         name  age    address        phone
# sn
# 1         AJ   19  Kathmandu   9878989898
# 2     Bigyan   34  Kathmandu  98689698689
# 3    Abhinav   15  Bhaktapur   8969698608
# 4   Shiwansh   12   Lalitpur   7149872421
# 5       Josh   45    Chitwan  80797079870
# 6      Harry   34      Kaski  98747377382

# %%
import pandas as pd
cols=['name','sn','phone']
df=pd.read_csv('data.csv',index_col='sn',usecols=cols)
df
# Out:
#         name        phone
# sn
# 1         AJ   9878989898
# 2     Bigyan  98689698689
# 3    Abhinav   8969698608
# 4   Shiwansh   7149872421
# 5       Josh  80797079870
# 6      Harry  98747377382

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='sn',)
df.iloc[1:4]
# Out:
#         name  age    address        phone
# sn
# 2     Bigyan   34  Kathmandu  98689698689
# 3    Abhinav   15  Bhaktapur   8969698608
# 4   Shiwansh   12   Lalitpur   7149872421

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='sn',)
df.loc[1:4]
# Out:
#         name  age    address        phone
# sn
# 1         AJ   19  Kathmandu   9878989898
# 2     Bigyan   34  Kathmandu  98689698689
# 3    Abhinav   15  Bhaktapur   8969698608
# 4   Shiwansh   12   Lalitpur   7149872421

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='name')
my_data=df.loc["AJ":"Abhinav"]
my_data.to_csv('newdata.csv')

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='sn')
df[df['address']=='Kathmandu']
# Out:
#       name  age    address        phone
# sn
# 1       AJ   19  Kathmandu   9878989898
# 2   Bigyan   34  Kathmandu  98689698689

# %%
import pandas as pd
df=pd.read_csv('data.csv',index_col='sn')
df[df['age']>=20]
# Out:
#       name  age    address        phone
# sn
# 2   Bigyan   34  Kathmandu  98689698689
# 5     Josh   45    Chitwan  80797079870
# 6    Harry   34      Kaski  98747377382

# %%
import pandas as pd
data={
    "Name":['AJ','Bigyan','Abhinav'],
    'Age':[12,19,98]
}
df=pd.DataFrame(data)
df.to_csv("Info.csv")
df
# Out:
#       Name  Age
# 0       AJ   12
# 1   Bigyan   19
# 2  Abhinav   98

# %%
import csv
data=[]
with open('data.csv') as csvfile:
    reader=csv.DictReader(csvfile)
    for row in reader:
        data.append(row)
        
data
# Out:
# [{'sn': '1',
#   'name': 'AJ',
#   'age': '19',
#   'address': 'Kathmandu',
#   'phone': '9878989898'},
#  {'sn': '2',
#   'name': 'Bigyan',
#   'age': '34',
#   'address': 'Kathmandu',
#   'phone': '98689698689'},
#  {'sn': '3',
#   'name': 'Abhinav',
#   'age': '15',
#   'address': 'Bhaktapur',
#   'phone': '8969698608'},
#  {'sn': '4',
#   'name': 'Shiwansh',
#   'age': '12',
#   'address': 'Lalitpur',
#   'phone': '7149872421'},
#  {'sn': '5',
#   'name': 'Josh',
#   'age': '45',
#   'address': 'Chitwan',
#   'phone': '80797079870'},
#  {'sn': '6',
#   'name': 'Harry',
#   'age': '34',
#   'address': 'Kaski',
#   'phone': '98747377382'}]
